# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# # **Coloured** Scatter plots:

# %%
iris= pd.read_csv('C:/Users/anike/OneDrive/Desktop/Data Visualisation/Datasets/Session 24/iris.csv')
iris.sample(5)
iris['Species']= iris['Species'].replace({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})
iris.sample(5)
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_30456\1013691788.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']= iris['Species'].replace({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 35    36            5.0           3.2            1.2           0.2        0
# 37    38            4.9           3.1            1.5           0.1        0
# 15    16            5.7           4.4            1.5           0.4        0
# 135  136            7.7           3.0            6.1           2.3        2
# 141  142            6.9           3.1            5.1           2.3        2

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='viridis', alpha=0.8)
plt.xlabel('Sepal length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ## **Summary**
# | Parameter        | Description                        |
# | ---------------- | ---------------------------------- |
# | `c='red'`        | Color (static)                     |
# | `c=values`       | Color (dynamic)                    |
# | `cmap='name'`    | Colormap used for dynamic coloring |
# | `s=values`       | Size of points                     |
# | `alpha=0.5`      | Transparency                       |
# | `plt.colorbar()` | Adds color legend                  |

# %% [markdown]
# ---
# # **Plot Size:**

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='viridis', alpha=0.8)
plt.xlabel('Sepal length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ---
# # **Annotations:**

# %% [markdown]
# Annotations are used to label specific data points.
# Syntax:<br>
# `plt.annotate(text, xy=(x, y), xytext=(xtext, ytext), arrowprops=dict(...))`<br><br>
# **Parameters:**
# | Parameter    | Purpose                          |
# | ------------ | -------------------------------- |
# | `text`       | The text to display              |
# | `xy`         | Point to annotate (x, y)         |
# | `xytext`     | Location of the text label       |
# | `arrowprops` | Dictionary to define arrow style |
# | `fontsize`   | Font size of the annotation text |
# | `color`      | Color of the annotation text     |

# %%
batter= pd.read_csv('Datasets/Session 24/batter.csv')
batter.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
from pandas.core.common import random_state
sample_df= batter.head(100).sample(25, random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
# plt.scatter(sample_df['avg'], sample_df['strike_rate'])
# for i in sample_df.itertuples():
#     plt.annotate(
#         i['batter'],
#         xy=(i['avg'][i], i['strike_rate'][i]),
#         textcoords='offset points',
#         xytext=(5, 5),
#         ha='left',
#         fontsize=8
#     )
# plt.xlabel("Batting Average")
# plt.ylabel("Strike Rate")
# plt.title("Player Performance")
# plt.grid(True)
# plt.show()

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s= sample_df['runs'])
for i in sample_df.itertuples():
    plt.annotate(
        i.batter,
        xy=(i.avg, i.strike_rate),
        textcoords='offset points',
        xytext=(5, 5),
        ha='left',
        fontsize=8
    )

# %% [markdown]
# # **Left for Now.**
# ---

# %% [markdown]
# # **Horizonatal and vertical lines:**

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s= sample_df['runs'])

plt.axhline(130, color='red')
plt.axvline(30, color='red')

for i in sample_df.itertuples():
    plt.annotate(
        i.batter,
        xy=(i.avg, i.strike_rate),
        textcoords='offset points',
        xytext=(5, 5),
        ha='left',
        fontsize=8
    )

# %% [markdown]
# ---
# # **Subplots:**

# %% [markdown]
# ## Understanding **figure** and **axis** object:
# 1. **Figure:**
# - The top level container that represents entire drawing surface or canvas.
# - Holds all other elements: Axes, title, legends, etc.
# 2. **Axes:**
# - region where data is plotted
# - A figure can contain **one or more** axes object.

# %% [markdown]
# ## Creating plots using **`plt.subplot()`**

# %%
fig, ax= plt.subplots(figsize=(18,10))
ax.scatter(batter['avg'],batter['strike_rate'])
ax.set_title('Player Performance')
ax.set_xlabel('Batting Average')
ax.set_ylabel('Strike Rate')
fig.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_30456\1547700934.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# - `plt.subplots()` returns a tuple containing the figure and axes objects.

# %%
fig, ax= plt.subplots(nrows= 2, ncols=1, sharex=True, figsize= (18,10))
ax[0].scatter(batter['avg'],batter['strike_rate'], color= 'orange')
ax[0].set_title('Player avg vs strike rate')
ax[0].set_xlabel('Batting Average')
ax[0].set_ylabel('Strike Rate')
ax[1].scatter(batter['avg'],batter['runs'], color= 'green')
ax[1].set_title('Player avg vs runs')
ax[1].set_xlabel('Runs')
ax[1].set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# ### Plotting **different** types of plots in **same** figure:

# %%
fig, ax= plt.subplots(nrows=2, ncols=2, figsize=(18,10))
ax[0][0].scatter(batter['avg'],batter['strike_rate'], color= 'orange')
ax[0][0].set_title('Player avg vs strike rate')
ax[0][0].set_xlabel('Batting Average')
ax[0][0].set_ylabel('Strike Rate')
ax[0][1].scatter(batter['avg'],batter['runs'], color= 'green')
ax[0][1].set_title('Player avg vs runs')
ax[0][1].set_xlabel('Runs')
ax[0][1].set_ylabel('Strike Rate')
ax[1][0].hist(batter['avg'])
ax[1][1].hist(batter['runs'], color='red')
fig.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_30456\444425723.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ---
# ## Creating plots using **`plt.figure()`:**

# %%
fig= plt.figure(figsize=(18,10))
ax1= fig.add_subplot(2,2,1)
ax1.scatter(batter['avg'], batter['strike_rate'], color='red')
ax2= fig.add_subplot(2,2,2)
ax2.hist(batter['runs'])
ax3= fig.add_subplot(2,2,3)
ax3.hist(batter['avg'], color='green')
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ---
# # **3D Plots:**

# %% [markdown]
# Creating a 3D plot on batters dataset with runs on x axis, avg on y axis and strike rate on z axis.

# %%
fig= plt.figure()
ax= plt.subplot(projection='3d')
ax.scatter3D(batter['runs'], batter['avg'], batter['strike_rate'])
ax.set_label('IPL Batsman Analysis')
ax.set_ylabel('Avg')
ax.set_zlabel('Strike Rate')
# Out:
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# ---
# # **3D Line plot:**

# %%
x=[0,1,5]
y=[0,10,13]
z=[0,13,20]
fig= plt.figure()
ax= plt.subplot(projection='3d')
ax.plot3D(x, y, z, color= 'red')

# %% [markdown]
# ---
# # **3D Surface Plots:**

# %%
x= np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx, yy= np.meshgrid(x, y)
z= xx**2 + yy**2
fig= plt.figure(figsize= (12,8))
ax= plt.subplot(projection= '3d')
p= ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %%
z= np.sin(xx) + np.cos(yy)
fig= plt.figure(figsize= (12,8))
ax= plt.subplot(projection= '3d')
p= ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ---
# # **Contour Plot:**

# %%
x= np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx, yy= np.meshgrid(x, y)
z= xx**2 + yy**2
fig= plt.figure(figsize= (12,8))
ax= plt.subplot()
p= ax.contour(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ## **Filled** Contour Plot

# %%
x= np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx, yy= np.meshgrid(x, y)
z= xx**2 + yy**2
fig= plt.figure(figsize= (12,8))
ax= plt.subplot()
p= ax.contourf(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# # **Heatmap:**

# %%
delivery= pd.read_csv('Datasets/Session 24/IPL_Ball_by_Ball_2008_2022.csv') 
delivery.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
temp_df= delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]
temp_df
# Out:
#              ID  innings  overs  ballnumber       batter             bowler  \
# 16      1312200        1      2           5  YBK Jaiswal     Mohammed Shami
# 22      1312200        1      3           5  YBK Jaiswal         Yash Dayal
# 103     1312200        1     17           2     TA Boult      R Sai Kishore
# 107     1312200        1     17           6     OC McCoy      R Sai Kishore
# 142     1312200        2      3           5      MS Wade  M Prasidh Krishna
# ...         ...      ...    ...         ...          ...                ...
# 225848   335982        1     19           2  BB McCullum            P Kumar
# 225852   335982        1     19           6  BB McCullum            P Kumar
# 225882   335982        2      4           4    JH Kallis         AB Agarkar
# 225932   335982        2     12           1      P Kumar          LR Shukla
# 225944   335982        2     13           6      P Kumar         SC Ganguly
#
# ...

# %%
grid= temp_df.pivot_table(index='overs', columns='ballnumber', values='batsman_run', aggfunc='count')

# %%
plt.figure(figsize=(12,6))
plt.imshow(grid)
plt.colorbar()

# %% [markdown]
# ---
# # **Pandas Plot**

# %% [markdown]
# ## On a series:

# %%
s= pd.Series([1,2,3,4,5,6,7])
s.plot(figsize=(3,4))
# Out:
# <Axes: >

# %%
s.plot(kind='bar', figsize=(3,4))
# Out:
# <Axes: >

# %% [markdown]
# ---

# %% [markdown]
# ## On a **Dataframe:**

# %%
tips= sns.load_dataset('tips')
tips.plot(kind= 'scatter',x= 'total_bill', y='tip' ,title= 'Cost analysis', marker='o', figsize=(10,6), c='sex', cmap='coolwarm')
# Out:
# <Axes: title={'center': 'Cost analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ---

# %% [markdown]
# ### 2D Plot:

# %%
stocks= pd.read_csv('Datasets/Session 24/weekly_stocks.csv')
stocks.head(5)
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks['MSFT'].plot(kind='line', figsize=(4,4))
# Out:
# <Axes: >

# %%
stocks.plot(kind= 'line', x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
stocks[['Date','AAPL', 'FB']].plot(kind='line', x='Date', figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## **Bar Chart** using pandas plot:

# %%
tips.groupby('sex')['total_bill'].mean().plot(kind='bar', figsize=(6,4), title='Average Total Bill')
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_30456\1480228432.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['total_bill'].mean().plot(kind='bar', figsize=(6,4), title='Average Total Bill')
# <Axes: title={'center': 'Average Total Bill'}, xlabel='sex'>

# %%
df= pd.read_csv('Datasets/Session 24/batsman_season_record.csv')
df.plot(kind= 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ---

# %% [markdown]
# ### Stacked Bar chart using pandas plot:

# %%
df.plot(kind= 'bar', stacked= True)
# Out:
# <Axes: >

# %% [markdown]
# ---

# %% [markdown]
# ## **Histograms:**

# %%
stocks.plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ---

# %% [markdown]
# ## Pie Chart using pandas plot:
# 1. Single Pie Chart:

# %%
df= pd.DataFrame(
    {
        'batsman': ['Dhawan', 'Rohit', 'Kohli', 'Sky', 'Pandya', 'Pant'],
        'match1': [120, 90, 35, 45, 12, 10],
        'match2': [130, 100, 40, 50, 15, 20],
        'match3': [140, 110, 45, 55, 18, 25]
    }
)
df
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120     130     140
# 1   Rohit      90     100     110
# 2   Kohli      35      40      45
# 3     Sky      45      50      55
# 4  Pandya      12      15      18
# 5    Pant      10      20      25

# %%
df['match1'].plot(kind='pie', labels= df['batsman'], autopct='%1.1f%%', figsize=(6,6), title='Match 1 Performance')
# Out:
# <Axes: title={'center': 'Match 1 Performance'}, ylabel='match1'>

# %% [markdown]
# 2. Multiple Pie Charts:

# %%
df[['match1', 'match2', 'match3']].plot(kind='pie', subplots=True, figsize=(15, 4), autopct='%1.1f%%', title='Match Performance')
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ### Multiple graphs:

# %%
stocks.plot(kind='line')
# Out:
# <Axes: >

# %%
stocks.plot(kind='line', subplots= True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ### On multiIndex Dataframes:

# %%
tips.pivot_table(index=['day', 'time'], columns=['sex' ,'smoker'], values='total_bill', aggfunc='mean').plot(kind='line', figsize=(10,6))
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_30456\3997704377.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index=['day', 'time'], columns=['sex' ,'smoker'], values='total_bill', aggfunc='mean').plot(kind='line', figsize=(10,6))
# <Axes: xlabel='day,time'>

# %% [markdown]
# ---
