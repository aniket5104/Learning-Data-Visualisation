# %%
import seaborn as sns

# %%
tips= sns.load_dataset('tips')
iris= sns.load_dataset('iris')

# %% [markdown]
# ---
# # **Categorical Plots:**
# ## Categorical **Scatter** plot:
# - Stripplot
# - Swarmplot
# ## Categorical **Distribution** plots:
# - Boxplot
# - Violinplot
# ## Categorical **Estimate** Plot:
# - Barplot
# - Pointplot
# - Countplot
# <br> <br>Figure level function- `catplot()`

# %% [markdown]
# ---
# # Categorical Scatter Plot:
# ## stripplot():
# 1. Using Axis level Function

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data= tips, x='day', y= 'total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data= tips, x='day', y= 'total_bill', jitter= False, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 2. Using Figure Level function:

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind= 'strip', hue= 'sex')

# %% [markdown]
# ---
# ## swarmplot():
# 1. using axis level function:

# %%
sns.swarmplot(data= tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 2. using figure level function:

# %%
sns.catplot(data= tips, x='day', y='total_bill', kind='swarm', hue='sex')

# %% [markdown]
# # Categorical Distribution Plot:
# ## Boxplot:
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary("minimum", first quartile[Q1], median, third quartile[Q3], and "maximum"). It can tell you outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tighly your data is grouped and if amd how your data is skewed.

# %% [markdown]
# 1. Using `boxplot()`:

# %%
sns.boxplot(data= tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 2. using `catplot()`:

# %%
sns.catplot(data= tips, x='day', y='total_bill', kind='box', hue= 'sex')

# %% [markdown]
# 3. single boxplot:

# %%
sns.boxplot(data= tips, y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ## Violin plot: (boxplot + kdeplot)
# 1. using axis level function: `violinplot()`

# %%
sns.violinplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 2. Using figure level function: `catplot()`

# %%
sns.catplot(data= tips, x='day', y='total_bill', kind='violin', hue='sex')

# %%
sns.catplot(data= tips, x='day', y='total_bill', kind='violin', hue='sex', split= True)

# %% [markdown]
# ---
# # Categorical Estimate Plots:
# ## **Barplot:**

# %%
import numpy as np
sns.barplot(data=tips, x= 'sex', y='total_bill', hue= 'smoker', estimator=np.min)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Point Plot:

# %%
import numpy as np
sns.pointplot(data=tips, x= 'sex', y='total_bill', hue= 'smoker', estimator=np.min,errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## **countplot:**

# %% [markdown]
# A special case of barplot, when you have to show the no. of observatioons in each category rather than computing a statistic for a second value. This is similar to a histogram over a categorical, rether tham quantitative variable.

# %%
sns.countplot(data=tips, x='sex', hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### **Faceting:**

# %%
sns.catplot(data=tips, x= 'sex', y='total_bill',col='smoker', row='time', kind='box')

# %% [markdown]
# ---
# # **Regression plot:**
# - regplot---> axis level function
# - lmplot---> figure leel function

# %%
sns.regplot(data= tips, x='total_bill', y='tip') # no hue parameter in regplot()
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data= tips, x='total_bill', y='tip', hue='sex')

# %% [markdown]
# ## **residual** plot:

# %%
sns.residplot(data= tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ---
# # **Multigrid Plots:**
# ## A second way to plot Facet grids: `facetgrid()` i.e. figure level function for facet grids.

# %% [markdown]
# A simple facet grid using `row=` and `col=`:

# %%
sns.catplot(data= tips, x='sex', y='total_bill', kind='violin', col='day')

# %%
g= sns.FacetGrid(data=tips, col='day', row= 'time', hue='smoker')
g.map(sns.violinplot,'sex','total_bill')
g.add_legend()
# Out:
# c:\Users\anike\OneDrive\Desktop\Data Visualisation\.venv\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ---
# # Plotting Pairwise Relatonship(PairGrid Vs Pairplot)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue='species')

# %%
g= sns.PairGrid(iris, hue= 'species')
g.map(sns.scatterplot)

# %%
g= sns.PairGrid(data= iris)
g.map_diag(sns.violinplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
# ---
# # **JoinGrid vs Joinplot:**

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind= 'scatter', hue= 'sex')

# %%
g= sns.JointGrid(data= tips, x='total_bill', y='tip')
g.plot(sns.scatterplot, sns.violinplot)

# %% [markdown]
# ---
# ## Datasets present in seaborn:

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
